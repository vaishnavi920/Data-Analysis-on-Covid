# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('latest Covid-19 India Status1.csv')

# %%
df.head()
# Out:
#         State/UTs  Total Cases  Active  Deaths  Active Ratio (%)  \
# 0     Maharashtra      6122893  117869  123857              1.93
# 1          Kerala      3011694  108400   14108              3.60
# 2       Karnataka      2862338   39626   35601              1.38
# 3      Tamil Nadu      2506848   34076   33196              1.36
# 4  Andhra Pradesh      1911231   32356   12919              1.69
#
#    Death Ratio (%)
# 0             2.02
# 1             0.47
# 2             1.24
# 3             1.32
# 4             0.68

# %%
df.shape
# Out:
# (36, 6)

# %%
(117869/6122893)*100
# Out:
# 1.9250540553297273

# %%
df.shape
# Out:
# (36, 6)

# %%
# Active=(df['Active']/df['Total Cases'])*100
# Active
# (117869/6122893)*100
# (34076/2506848)*100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UTs         36 non-null     object
#  1   Total Cases       36 non-null     int64
#  2   Active            36 non-null     int64
#  3   Deaths            36 non-null     int64
#  4   Active Ratio (%)  36 non-null     float64
#  5   Death Ratio (%)   36 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.8+ KB

# %%
df.isnull().sum()
# Out:
# State/UTs           0
# Total Cases         0
# Active              0
# Deaths              0
# Active Ratio (%)    0
# Death Ratio (%)     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Deaths', 'Active Ratio (%)',
#        'Death Ratio (%)'],
#       dtype='object')

# %%
df.columns = ['State', 'Total_Cases', 'Active', 'Deaths', 'Active_Ratio', 'Death_Ratio']

# %%
df.head()
# Out:
#             State  Total_Cases  Active  Deaths  Active_Ratio  Death_Ratio
# 0     Maharashtra      6122893  117869  123857          1.93         2.02
# 1          Kerala      3011694  108400   14108          3.60         0.47
# 2       Karnataka      2862338   39626   35601          1.38         1.24
# 3      Tamil Nadu      2506848   34076   33196          1.36         1.32
# 4  Andhra Pradesh      1911231   32356   12919          1.69         0.68

# %%
df.sort_values('Active_Ratio',ascending=False)
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 30                                   Mizoram        22703    3960     100
# 31                                    Sikkim        21573    1975     311
# 24                                   Manipur        74341    6534    1229
# 28                         Arunachal Pradesh        38283    3363     184
# 27                                 Meghalaya        52712    4229     886
# 25                                   Tripura        69019    4122     703
# 17                                     Assam       524556   23371    4743
# 29                                  Nagaland        25663    1070     505
# 1                                     Kerala      3011694  108400   14108
# 10                                    Odisha       929788   25148    4358
# 34                               Lakshadweep         9965     246      49
# 0                                Maharashtra      6122893  117869  123857
# ...

# %%
df.groupby('State')['Active_Ratio'].sum().sort_values(ascending=False)
# Out:
# State
# Mizoram                                     17.44
# Sikkim                                       9.15
# Manipur                                      8.79
# Arunachal Pradesh                            8.78
# Meghalaya                                    8.02
# Tripura                                      5.97
# Assam                                        4.46
# Nagaland                                     4.17
# Kerala                                       3.60
# Odisha                                       2.70
# Lakshadweep                                  2.47
# Maharashtra                                  1.93
# Telengana                                    1.82
# Andhra Pradesh                               1.69
# Puducherry                                   1.48
# Karnataka                                    1.38
# Tamil Nadu                                   1.36
# Goa                                          1.16
# West Bengal                                  1.10
# ...

# %%
df.sort_values(['Active_Ratio'],ascending=False)
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 30                                   Mizoram        22703    3960     100
# 31                                    Sikkim        21573    1975     311
# 24                                   Manipur        74341    6534    1229
# 28                         Arunachal Pradesh        38283    3363     184
# 27                                 Meghalaya        52712    4229     886
# 25                                   Tripura        69019    4122     703
# 17                                     Assam       524556   23371    4743
# 29                                  Nagaland        25663    1070     505
# 1                                     Kerala      3011694  108400   14108
# 10                                    Odisha       929788   25148    4358
# 34                               Lakshadweep         9965     246      49
# 0                                Maharashtra      6122893  117869  123857
# ...

# %%
df.sort_values(by='Active_Ratio',ascending=False)
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 30                                   Mizoram        22703    3960     100
# 31                                    Sikkim        21573    1975     311
# 24                                   Manipur        74341    6534    1229
# 28                         Arunachal Pradesh        38283    3363     184
# 27                                 Meghalaya        52712    4229     886
# 25                                   Tripura        69019    4122     703
# 17                                     Assam       524556   23371    4743
# 29                                  Nagaland        25663    1070     505
# 1                                     Kerala      3011694  108400   14108
# 10                                    Odisha       929788   25148    4358
# 34                               Lakshadweep         9965     246      49
# 0                                Maharashtra      6122893  117869  123857
# ...

# %%
df.groupby('State')['Active_Ratio'].agg(['sum']).sort_values(by='sum',ascending=False)
# Out:
#                                             sum
# State
# Mizoram                                   17.44
# Sikkim                                     9.15
# Manipur                                    8.79
# Arunachal Pradesh                          8.78
# Meghalaya                                  8.02
# Tripura                                    5.97
# Assam                                      4.46
# Nagaland                                   4.17
# Kerala                                     3.60
# Odisha                                     2.70
# Lakshadweep                                2.47
# Maharashtra                                1.93
# Telengana                                  1.82
# Andhra Pradesh                             1.69
# Puducherry                                 1.48
# Karnataka                                  1.38
# Tamil Nadu                                 1.36
# Goa                                        1.16
# ...

# %%
plt.figure(figsize=(10,4),dpi=200)
plt.plot(df['State'],df['Active_Ratio'],color='red',marker='o',markersize=10)
plt.xticks(rotation=90,fontsize=11)
plt.yticks(fontsize=13.5)
plt.xlabel('State', fontsize=15)
plt.ylabel('Active Ratio', fontsize=15)
plt.title("Line Plot for Active Ratio",fontsize=15)
plt.show()

# %%
q=df.sort_values(by='Total_Cases',ascending=False)
q=q.head(10)
q
# Out:
#             State  Total_Cases  Active  Deaths  Active_Ratio  Death_Ratio
# 0     Maharashtra      6122893  117869  123857          1.93         2.02
# 1          Kerala      3011694  108400   14108          3.60         0.47
# 2       Karnataka      2862338   39626   35601          1.38         1.24
# 3      Tamil Nadu      2506848   34076   33196          1.36         1.32
# 4  Andhra Pradesh      1911231   32356   12919          1.69         0.68
# 5   Uttar Pradesh      1706934    1947   22666          0.11         1.33
# 6     West Bengal      1508223   16655   17850          1.10         1.18
# 7           Delhi      1434780     858   25005          0.06         1.74
# 8    Chhattisgarh       996689    5017   13464          0.50         1.35
# 9       Rajasthan       952887     935    8942          0.10         0.94

# %%
plt.pie(q['Total_Cases'],labels=q['State'],autopct='%0.0f%%');

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='State',y='Total_Cases',data=df.head(10))
plt.xticks(rotation=90);

# %%
'''  Toatal Cases in each state'''
total_cases_state = df.groupby(['State'])['Total_Cases'].max().sort_values(ascending=False).reset_index()
total_cases_state.head()
# Out:
#             State  Total_Cases
# 0     Maharashtra      6122893
# 1          Kerala      3011694
# 2       Karnataka      2862338
# 3      Tamil Nadu      2506848
# 4  Andhra Pradesh      1911231

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=75)
sns.barplot(x='State', y='Total_Cases',data=total_cases_state.head(5))
plt.title('Total Cases in Each State', fontsize=20)
plt.xlabel('State', fontsize=30)
plt.ylabel('Total Cases', fontsize=15);

# %%
1*(10**6)*6
# Out:
# 6000000

# %% [markdown]
# *Maharashtra has the highest number of total cases in India, Kerala and Karnataka rank second and third although there is not much difference between their total counts. *

# %%
top_10 = total_cases_state[:10]

# %%
top_10
# Out:
#             State  Total_Cases
# 0     Maharashtra      6122893
# 1          Kerala      3011694
# 2       Karnataka      2862338
# 3      Tamil Nadu      2506848
# 4  Andhra Pradesh      1911231
# 5   Uttar Pradesh      1706934
# 6     West Bengal      1508223
# 7           Delhi      1434780
# 8    Chhattisgarh       996689
# 9       Rajasthan       952887

# %%
# ''' pie chart of active cases in top 5 states in india'''
# # plt.figure(figsize=(8,8))
# L=[0.7,0,0,0,0]
# plt.pie(x='Total_Cases', data=total_cases_state.head(10),  labels='State',autopct='%.1f%%',radius=0.7,explode=L,shadow=True,startangle=90)
# plt.title("Active Cases in Top 5 states in India", fontsize = 15) 
# # plt.legend(loc='right')
# plt.show()

# %%
df.sort_values(by='Death_Ratio',ascending=False)
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 16                                    Punjab       596970    1964   16141
# 19                               Uttarakhand       340959    1506    7338
# 0                                Maharashtra      6122893  117869  123857
# 29                                  Nagaland        25663    1070     505
# 22                                       Goa       168015    1950    3082
# 7                                      Delhi      1434780     858   25005
# 21                          Himachal Pradesh       203117    1338    3486
# 35                       Andaman and Nicobar         7491      14     128
# 27                                 Meghalaya        52712    4229     886
# 24                                   Manipur        74341    6534    1229
# 23                                Puducherry       118416    1753    1765
# 18                                 Jharkhand       346113     532    5118
# ...

# %%
plt.figure(figsize=(9,6))
plt.title("Line Plot for Active Ratio",fontsize=15)

plt.plot(df['State'],df['Active_Ratio'],color='blue',marker='o',label='Active cases')
plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5)
plt.xlabel('State', fontsize=15)
# plt.legend()

plt.ylabel('Active Ratio', fontsize=15)

plt.plot(df['State'],df['Death_Ratio'],color='k',marker='*',label='death')
plt.legend()
plt.show()

# %%
df
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 0                                Maharashtra      6122893  117869  123857
# 1                                     Kerala      3011694  108400   14108
# 2                                  Karnataka      2862338   39626   35601
# 3                                 Tamil Nadu      2506848   34076   33196
# 4                             Andhra Pradesh      1911231   32356   12919
# 5                              Uttar Pradesh      1706934    1947   22666
# 6                                West Bengal      1508223   16655   17850
# 7                                      Delhi      1434780     858   25005
# 8                               Chhattisgarh       996689    5017   13464
# 9                                  Rajasthan       952887     935    8942
# 10                                    Odisha       929788   25148    4358
# 11                                   Gujarat       824029    1969   10072
# ...

# %%
df.tail(5)
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 31                                    Sikkim        21573    1975     311
# 32                                    Ladakh        20143     183     204
# 33  Dadra and Nagar Haveli and Daman and Diu        10576      38       4
# 34                               Lakshadweep         9965     246      49
# 35                       Andaman and Nicobar         7491      14     128
#
#     Active_Ratio  Death_Ratio
# 31          9.15         1.44
# 32          0.91         1.01
# 33          0.36         0.04
# 34          2.47         0.49
# 35          0.19         1.71

# %%
df['State'].value_counts().head(4)
# Out:
# Maharashtra          1
# Kerala               1
# Jammu and Kashmir    1
# Himachal Pradesh     1
# Name: State, dtype: int64

# %%
L=['blue','white','blue','white']
plt.pie(df['State'].value_counts().head(4).values,labels=df['State'].value_counts().head(4).index,colors=L,startangle=135);

# %%
''' pie chart of total cases in top 5 states in India '''
plt.figure(figsize=(7,7))

l=['silver','gold','grey','violet','white']
plt.pie(x='Total_Cases', data=df.head(10),colors=l, labels='State', startangle=90,autopct='%.f%%')
plt.title("Total Cases in Top 5 states in India", fontsize = 24) 
plt.tight_layout() 
plt.show()

# %%
117869+123857
# Out:
# 241726

# %%
df.head()
# Out:
#             State  Total_Cases  Active  Deaths  Active_Ratio  Death_Ratio
# 0     Maharashtra      6122893  117869  123857          1.93         2.02
# 1          Kerala      3011694  108400   14108          3.60         0.47
# 2       Karnataka      2862338   39626   35601          1.38         1.24
# 3      Tamil Nadu      2506848   34076   33196          1.36         1.32
# 4  Andhra Pradesh      1911231   32356   12919          1.69         0.68

# %%
''' caculating Recovered_Cases '''
df['recovered_cases'] = df['Total_Cases'] - (df['Active'] + df['Deaths'])
df
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 0                                Maharashtra      6122893  117869  123857
# 1                                     Kerala      3011694  108400   14108
# 2                                  Karnataka      2862338   39626   35601
# 3                                 Tamil Nadu      2506848   34076   33196
# 4                             Andhra Pradesh      1911231   32356   12919
# 5                              Uttar Pradesh      1706934    1947   22666
# 6                                West Bengal      1508223   16655   17850
# 7                                      Delhi      1434780     858   25005
# 8                               Chhattisgarh       996689    5017   13464
# 9                                  Rajasthan       952887     935    8942
# 10                                    Odisha       929788   25148    4358
# 11                                   Gujarat       824029    1969   10072
# ...

# %%
df
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 0                                Maharashtra      6122893  117869  123857
# 1                                     Kerala      3011694  108400   14108
# 2                                  Karnataka      2862338   39626   35601
# 3                                 Tamil Nadu      2506848   34076   33196
# 4                             Andhra Pradesh      1911231   32356   12919
# 5                              Uttar Pradesh      1706934    1947   22666
# 6                                West Bengal      1508223   16655   17850
# 7                                      Delhi      1434780     858   25005
# 8                               Chhattisgarh       996689    5017   13464
# 9                                  Rajasthan       952887     935    8942
# 10                                    Odisha       929788   25148    4358
# 11                                   Gujarat       824029    1969   10072
# ...

# %%
df['recovered ratio']=(df['recovered_cases']/df['Total_Cases'])*100

# %%
df
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 0                                Maharashtra      6122893  117869  123857
# 1                                     Kerala      3011694  108400   14108
# 2                                  Karnataka      2862338   39626   35601
# 3                                 Tamil Nadu      2506848   34076   33196
# 4                             Andhra Pradesh      1911231   32356   12919
# 5                              Uttar Pradesh      1706934    1947   22666
# 6                                West Bengal      1508223   16655   17850
# 7                                      Delhi      1434780     858   25005
# 8                               Chhattisgarh       996689    5017   13464
# 9                                  Rajasthan       952887     935    8942
# 10                                    Odisha       929788   25148    4358
# 11                                   Gujarat       824029    1969   10072
# ...

# %%
L=[1,100]
a=[[1,2,3,4,5],[16,17,18,19,20],[]
b=[[6,10],
c=11,15

# %%
plt.figure(figsize=(10,4))
plt.plot(df['State'],df['Active_Ratio'],color='blue',marker='o',label='Active cases')
plt.plot(df['State'],df['Death_Ratio'],color='k',marker='*',label='death')
plt.plot(df['State'],df['recovered ratio'],color='green',marker='*',label='recovered')

plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5)
plt.xlabel('State', fontsize=15)


plt.ylabel('Active Ratio', fontsize=15)
plt.title("Line Plot for Active Ratio",fontsize=15)


plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['State'],df['Active'],color='blue',marker='o',label='Active cases')
plt.plot(df['State'],df['Deaths'],color='k',marker='*',label='death')
plt.plot(df['State'],df['recovered_cases'],color='green',marker='*',label='recovered')

plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5)
plt.xlabel('State', fontsize=15)


plt.ylabel('Active Ratio', fontsize=15)
plt.title("Line Plot for Active Ratio",fontsize=15)


plt.legend()
plt.show()

# %%
df.sort_values(by='recovered_cases',ascending=False)

# %%
rec_cases = df.groupby('State')['recovered_cases'].max().sort_values(ascending=False).reset_index()
rec_cases
# Out:
#                                        State  recovered_cases
# 0                                Maharashtra          5881167
# 1                                     Kerala          2889186
# 2                                  Karnataka          2787111
# 3                                 Tamil Nadu          2439576
# 4                             Andhra Pradesh          1865956
# 5                              Uttar Pradesh          1682321
# 6                                West Bengal          1473718
# 7                                      Delhi          1408917
# 8                               Chhattisgarh           978208
# 9                                  Rajasthan           943010
# 10                                    Odisha           900282
# 11                                   Gujarat           811988
# 12                            Madhya Pradesh           780610
# 13                                   Haryana           758512
# ...

# %%
df
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 0                                Maharashtra      6122893  117869  123857
# 1                                     Kerala      3011694  108400   14108
# 2                                  Karnataka      2862338   39626   35601
# 3                                 Tamil Nadu      2506848   34076   33196
# 4                             Andhra Pradesh      1911231   32356   12919
# 5                              Uttar Pradesh      1706934    1947   22666
# 6                                West Bengal      1508223   16655   17850
# 7                                      Delhi      1434780     858   25005
# 8                               Chhattisgarh       996689    5017   13464
# 9                                  Rajasthan       952887     935    8942
# 10                                    Odisha       929788   25148    4358
# 11                                   Gujarat       824029    1969   10072
# ...

# %%
sns.lineplot(x='State',y='Total_Cases',data=df)
sns.lineplot(x='State',y='Active',data=df)
sns.lineplot(x='State',y='recovered_cases',data=df)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 3
#       1 sns.lineplot(x='State',y='Total_Cases',data=df)
#       2 sns.lineplot(x='State',y='Active',data=df)
# ----> 3 sns.lineplot(x='State',y='recovered_cases',data=df)
#       5 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
# ...

# %%
df
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 0                                Maharashtra      6122893  117869  123857
# 1                                     Kerala      3011694  108400   14108
# 2                                  Karnataka      2862338   39626   35601
# 3                                 Tamil Nadu      2506848   34076   33196
# 4                             Andhra Pradesh      1911231   32356   12919
# 5                              Uttar Pradesh      1706934    1947   22666
# 6                                West Bengal      1508223   16655   17850
# 7                                      Delhi      1434780     858   25005
# 8                               Chhattisgarh       996689    5017   13464
# 9                                  Rajasthan       952887     935    8942
# 10                                    Odisha       929788   25148    4358
# 11                                   Gujarat       824029    1969   10072
# ...
